# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import load_model

# %%
# 학습된 모델 불러오기
model = load_model('/content/drive/MyDrive/Colab Notebooks/인공지능/10주차/mnist.model.h5')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               200960
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 300,938
# Trainable params: 300,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# 테스트할 이미지 확인하기
width = 28
height = 28
test_num = plt.imread('/content/drive/MyDrive/Colab Notebooks/인공지능/10주차/my/color.jpg')
plt.imshow(test_num)

# %%
# 컬러 이미지를 흑백 이미지로 변환
test_num = cv2.cvtColor(test_num, cv2.COLOR_BGR2GRAY)
test_num.shape
# Out:
# (28, 28)

# %%
# 모델이 예측한 값 확인하기
test_num = test_num.reshape(1, width*height).astype('float32')/255.0
print('Prediction : ', model.predict(test_num))
# Out:
# Prediction :  [[9.9999571e-01 3.7293332e-13 2.0038364e-16 4.0835228e-13 5.0267135e-19
#   2.8900804e-06 1.5668696e-10 1.4442818e-06 5.8664072e-12 8.3054430e-10]]

# %%
import numpy as np

# 클래스 확인하기
x = model.predict(test_num)
class_x = np.argmax(x, axis=1)
class_x
# Out:
# array([0])

# %%
# 흑백 이미지 확인
plt.figure(figsize=(12,12))

for i in range(9):
  plt.subplot(3, 3, i+1)
  img_path = '/content/drive/MyDrive/Colab Notebooks/인공지능/10주차/my/my_' + str(i+1) +'.jpg'
  test_num = plt.imread(img_path)
  plt.imshow(test_num, cmap='gray')
  test_num = test_num.reshape(1, width*height).astype('float32')/255.0
  tmp = 'Prediction : ' + str(np.argmax(model.predict(test_num), axis=1))
  plt.title(tmp)

plt.show()

# %%
test_num.shape
# Out:
# (1, 784)

# %%
plt.figure(figsize=(12,12))

# 흑백 이미지들에 대한 예측값 확인하기



plt.show()
